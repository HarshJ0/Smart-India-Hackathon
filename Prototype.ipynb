# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline

# %%
IMG_SHAPE = 128
BATCH_SIZE = 64
EPOCHS = 50

# %%
def load_dataset():
    X = []
    y = []
    for path in glob.glob('normaltrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([0])
    for path in glob.glob('overtrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([1])
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
X, y = load_dataset()
X.shape, y.shape
# Out:
# ((148, 128, 128, 3), (148, 1))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
X_train.shape, y_train.shape
# Out:
# ((118, 128, 128, 3), (118, 1))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((IMG_SHAPE,IMG_SHAPE,3)),
    tf.keras.applications.MobileNet(include_top=False, weights='imagenet'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation=tf.keras.layers.LeakyReLU(0.01)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(1e-4), metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, None, None, 1024)  3228864
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                1048640
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,277,569
# Trainable params: 4,255,681
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, validation_batch_size=8, shuffle=True)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.1722 - accuracy: 0.5705 - val_loss: 2.9821 - val_accuracy: 0.3333
# Epoch 2/50
# 2/2 [==============================] - 4s 1s/step - loss: 0.2095 - accuracy: 0.9030 - val_loss: 1.6889 - val_accuracy: 0.5417
# Epoch 3/50
# 2/2 [==============================] - 4s 1s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8761 - val_accuracy: 0.7083
# Epoch 4/50
# 2/2 [==============================] - 4s 1s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5254 - val_accuracy: 0.7917
# Epoch 5/50
# 2/2 [==============================] - 4s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3680 - val_accuracy: 0.8750
# Epoch 6/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0178 - accuracy: 0.9929 - val_loss: 0.3034 - val_accuracy: 0.8333
# Epoch 7/50
# 2/2 [==============================] - 4s 1s/step - loss: 9.8265e-04 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.8333
# Epoch 8/50
# 2/2 [==============================] - 5s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.8333
# Epoch 9/50
# 2/2 [==============================] - 5s 2s/step - loss: 5.2155e-04 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.8333
# Epoch 10/50
# 2/2 [==============================] - 6s 2s/step - loss: 8.0580e-04 - accuracy: 1.0000 - val_loss: 0.2380 - val_accuracy: 0.8333
# Epoch 11/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.1157e-04 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.8333
# Epoch 12/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.6399e-04 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.8333
# Epoch 13/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.2014e-04 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.8750
# Epoch 14/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.8605e-04 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.8750
# Epoch 15/50
# 2/2 [==============================] - 6s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.8750
# Epoch 16/50
# 2/2 [==============================] - 5s 2s/step - loss: 2.1285e-04 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.8750
# Epoch 17/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.5599e-04 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.8750
# Epoch 18/50
# 2/2 [==============================] - 6s 2s/step - loss: 9.2381e-05 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.8750
# Epoch 19/50
# 2/2 [==============================] - 6s 2s/step - loss: 9.8697e-05 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9167
# Epoch 20/50
# 2/2 [==============================] - 6s 2s/step - loss: 1.0564e-04 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9167
# Epoch 21/50
# 2/2 [==============================] - 6s 2s/step - loss: 8.3422e-05 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9167
# Epoch 22/50
# 2/2 [==============================] - 6s 2s/step - loss: 6.4727e-05 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9167
# Epoch 23/50
# 2/2 [==============================] - 6s 2s/step - loss: 6.3273e-05 - accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9167
# Epoch 24/50
# 2/2 [==============================] - 6s 2s/step - loss: 4.5523e-05 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9167
# Epoch 25/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.1091e-05 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9167
# Epoch 26/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.2759e-05 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9167
# Epoch 27/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.8438e-05 - accuracy: 1.0000 - val_loss: 0.1719 - val_accuracy: 0.9167
# Epoch 28/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.5316e-05 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9167
# Epoch 29/50
# 2/2 [==============================] - 6s 2s/step - loss: 8.2032e-05 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9167
# Epoch 30/50
# 2/2 [==============================] - 6s 2s/step - loss: 7.2808e-05 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9167
# Epoch 31/50
# 2/2 [==============================] - 6s 2s/step - loss: 4.4704e-05 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9167
# Epoch 32/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.4929e-05 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9167
# Epoch 33/50
# 2/2 [==============================] - 6s 2s/step - loss: 6.8178e-05 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9167
# Epoch 34/50
# 2/2 [==============================] - 6s 2s/step - loss: 1.1041e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9167
# Epoch 35/50
# 2/2 [==============================] - 6s 2s/step - loss: 4.2280e-05 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9167
# Epoch 36/50
# 2/2 [==============================] - 6s 2s/step - loss: 4.7593e-05 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9167
# Epoch 37/50
# 2/2 [==============================] - 6s 2s/step - loss: 5.5596e-05 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9167
# Epoch 38/50
# 2/2 [==============================] - 6s 2s/step - loss: 1.4079e-04 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9167
# Epoch 39/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.1342e-05 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9167
# Epoch 40/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.7963e-05 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9583
# Epoch 41/50
# 2/2 [==============================] - 5s 2s/step - loss: 4.1839e-05 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9583
# Epoch 42/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.6359e-05 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9583
# Epoch 43/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.8057e-05 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9583
# Epoch 44/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.4455e-05 - accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9583
# Epoch 45/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.4781e-05 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9583
# Epoch 46/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.5843e-05 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9583
# Epoch 47/50
# 2/2 [==============================] - 6s 2s/step - loss: 6.7354e-05 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9583
# Epoch 48/50
# 2/2 [==============================] - 6s 2s/step - loss: 3.2279e-05 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.8519e-05 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.5215e-05 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 1.0000

# %%
def predict(path):
    img = tf.keras.preprocessing.image.load_img(path)
    img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
    pred = model.predict(np.array([img]))[0]
    plt.imshow(img)
    if (pred >= 0.6):
        plt.title('Truck is overloaded')
    elif (pred > 0.4) and (pred < 0.6):
        plt.title("Not Sure")
    else:
        plt.title("Truck is not Overloaded")
    plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 1s 885ms/step - loss: 0.0205 - accuracy: 1.0000
# [0.02046053856611252, 1.0]

# %%
predict('normaltrucks/01-NT.jpg')

# %%
predict('overtrucks/02-OT.jpg')

# %%
predict('overtrucks/68-OT.jpg')

# %%
predict('overtrucks/84-OT.jpg')

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter.filedialog import askopenfile
from PIL import Image, ImageTk
my_w = tk.Tk()
my_w.geometry("430x500")
my_w.title('Prototype')
my_font1=('times', 18, 'bold')
l1 = tk.Label(my_w,text='Add any photo of a commercial vehicle',width=30,font=my_font1)  
l1.grid(row=1,column=1)
b1 = tk.Button(my_w, text='Upload File', 
   width=20,command = lambda:upload_file())
b1.grid(row=2,column=1) 

def upload_file():
    global img, path
    f_types = [('testing', '*.jpg')]
    filename = filedialog.askopenfilename(filetypes=f_types)
    img = ImageTk.PhotoImage(file=filename)
    #path = filedialog.askopenfilename(initialdir=os.getcwd())
    predict(filename)
    b2 =tk.Button(my_w,image=img)
    b2.grid(row=3,column=1)

my_w.mainloop()
