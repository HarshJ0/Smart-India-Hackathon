# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import tensorflow as tf
#       4 import matplotlib.pyplot as plt
#       5 import os
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
IMG_SHAPE = 128
BATCH_SIZE = 64
EPOCHS = 50

# %%
def load_dataset():
    X = []
    y = []
    for path in glob.glob('normaltrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([0])
    for path in glob.glob('overtrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([1])
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
X, y = load_dataset()
X.shape, y.shape

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
X_train.shape, y_train.shape

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((IMG_SHAPE,IMG_SHAPE,3)),
    tf.keras.applications.MobileNet(include_top=False, weights='imagenet'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation=tf.keras.layers.LeakyReLU(0.01)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(1e-4), metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, None, None, 1024)  3228864
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1048640
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,277,569
# Trainable params: 4,255,681
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, validation_batch_size=8, shuffle=True)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 41s 17s/step - loss: 1.1314 - accuracy: 0.4815 - val_loss: 0.1679 - val_accuracy: 0.9167
# Epoch 2/50
# 2/2 [==============================] - 7s 2s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9583
# Epoch 3/50
# 2/2 [==============================] - 7s 2s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2140 - val_accuracy: 0.9167
# Epoch 4/50
# 2/2 [==============================] - 7s 2s/step - loss: 7.6037e-04 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9167
# Epoch 5/50
# 2/2 [==============================] - 14s 6s/step - loss: 4.9351e-04 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9167
# Epoch 6/50
# 2/2 [==============================] - 11s 6s/step - loss: 9.7884e-04 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.9167
# Epoch 7/50
# 2/2 [==============================] - 6s 2s/step - loss: 2.6044e-04 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 0.9167
# Epoch 8/50
# 2/2 [==============================] - 10s 6s/step - loss: 1.5460e-04 - accuracy: 1.0000 - val_loss: 0.3671 - val_accuracy: 0.9167
# Epoch 9/50
# 2/2 [==============================] - 7s 2s/step - loss: 7.8673e-05 - accuracy: 1.0000 - val_loss: 0.3696 - val_accuracy: 0.9167
# Epoch 10/50
# 2/2 [==============================] - 7s 2s/step - loss: 2.9198e-04 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9167
# Epoch 11/50
# 2/2 [==============================] - 7s 3s/step - loss: 5.8729e-05 - accuracy: 1.0000 - val_loss: 0.3689 - val_accuracy: 0.9167
# Epoch 12/50
# 2/2 [==============================] - 7s 2s/step - loss: 5.5805e-05 - accuracy: 1.0000 - val_loss: 0.3678 - val_accuracy: 0.9167
# Epoch 13/50
# 2/2 [==============================] - 7s 2s/step - loss: 3.1664e-05 - accuracy: 1.0000 - val_loss: 0.3642 - val_accuracy: 0.9167
# Epoch 14/50
# 2/2 [==============================] - 14s 6s/step - loss: 4.3474e-05 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9167
# Epoch 15/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.4319e-05 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 0.9167
# Epoch 16/50
# 2/2 [==============================] - 9s 2s/step - loss: 1.9104e-05 - accuracy: 1.0000 - val_loss: 0.3589 - val_accuracy: 0.9167
# Epoch 17/50
# 2/2 [==============================] - 7s 3s/step - loss: 4.8946e-05 - accuracy: 1.0000 - val_loss: 0.3544 - val_accuracy: 0.9167
# Epoch 18/50
# 2/2 [==============================] - 10s 2s/step - loss: 1.2893e-05 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9167
# Epoch 19/50
# 2/2 [==============================] - 14s 5s/step - loss: 1.6751e-05 - accuracy: 1.0000 - val_loss: 0.3485 - val_accuracy: 0.9167
# Epoch 20/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.0413e-05 - accuracy: 1.0000 - val_loss: 0.3458 - val_accuracy: 0.9167
# Epoch 21/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.2705e-05 - accuracy: 1.0000 - val_loss: 0.3443 - val_accuracy: 0.9167
# Epoch 22/50
# 2/2 [==============================] - 10s 6s/step - loss: 1.1747e-05 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9167
# Epoch 23/50
# 2/2 [==============================] - 10s 6s/step - loss: 1.4269e-05 - accuracy: 1.0000 - val_loss: 0.3440 - val_accuracy: 0.9167
# Epoch 24/50
# 2/2 [==============================] - 10s 4s/step - loss: 1.6871e-05 - accuracy: 1.0000 - val_loss: 0.3440 - val_accuracy: 0.9167
# Epoch 25/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.0139e-05 - accuracy: 1.0000 - val_loss: 0.3415 - val_accuracy: 0.9167
# Epoch 26/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.2826e-05 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.9167
# Epoch 27/50
# 2/2 [==============================] - 7s 2s/step - loss: 8.4560e-06 - accuracy: 1.0000 - val_loss: 0.3362 - val_accuracy: 0.9167
# Epoch 28/50
# 2/2 [==============================] - 10s 6s/step - loss: 1.4139e-05 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9167
# Epoch 29/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.1041e-05 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 0.9167
# Epoch 30/50
# 2/2 [==============================] - 10s 6s/step - loss: 4.4224e-05 - accuracy: 1.0000 - val_loss: 0.3272 - val_accuracy: 0.9167
# Epoch 31/50
# 2/2 [==============================] - 10s 4s/step - loss: 1.3091e-04 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9167
# Epoch 32/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.6796e-04 - accuracy: 1.0000 - val_loss: 0.3181 - val_accuracy: 0.9167
# Epoch 33/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.9716e-05 - accuracy: 1.0000 - val_loss: 0.3090 - val_accuracy: 0.9167
# Epoch 34/50
# 2/2 [==============================] - 8s 3s/step - loss: 1.3905e-04 - accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.9583
# Epoch 35/50
# 2/2 [==============================] - 7s 2s/step - loss: 7.0747e-06 - accuracy: 1.0000 - val_loss: 0.2837 - val_accuracy: 0.9583
# Epoch 36/50
# 2/2 [==============================] - 11s 6s/step - loss: 1.2448e-05 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9583
# Epoch 37/50
# 2/2 [==============================] - 11s 6s/step - loss: 1.1955e-05 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9583
# Epoch 38/50
# 2/2 [==============================] - 10s 5s/step - loss: 8.8808e-06 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9583
# Epoch 39/50
# 2/2 [==============================] - 10s 4s/step - loss: 2.1583e-05 - accuracy: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.9583
# Epoch 40/50
# 2/2 [==============================] - 14s 6s/step - loss: 5.7709e-06 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9583
# Epoch 41/50
# 2/2 [==============================] - 7s 2s/step - loss: 1.6153e-05 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9583
# Epoch 42/50
# 2/2 [==============================] - 10s 2s/step - loss: 7.5115e-06 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9583
# Epoch 43/50
# 2/2 [==============================] - 11s 6s/step - loss: 1.1959e-05 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9583
# Epoch 44/50
# 2/2 [==============================] - 6s 2s/step - loss: 8.0970e-06 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9583
# Epoch 45/50
# 2/2 [==============================] - 5s 3s/step - loss: 7.3345e-06 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9583
# Epoch 46/50
# 2/2 [==============================] - 4s 2s/step - loss: 7.4854e-06 - accuracy: 1.0000 - val_loss: 0.1804 - val_accuracy: 0.9583
# Epoch 47/50
# 2/2 [==============================] - 5s 2s/step - loss: 4.3286e-05 - accuracy: 1.0000 - val_loss: 0.1739 - val_accuracy: 0.9583
# Epoch 48/50
# 2/2 [==============================] - 6s 2s/step - loss: 6.5163e-06 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9583
# Epoch 49/50
# 2/2 [==============================] - 6s 2s/step - loss: 9.9381e-06 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9583
# Epoch 50/50
# 2/2 [==============================] - 6s 3s/step - loss: 6.6059e-06 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9583

# %%
def predict(path):
    img = tf.keras.preprocessing.image.load_img(path)
    img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
    pred = model.predict(np.array([img]))[0]
    plt.imshow(img)
    if (pred >= 0.6):
        plt.title('Truck is overloaded')
    elif (pred > 0.4) and (pred < 0.6):
        plt.title("Not Sure")
    else:
        plt.title("Truck is not Overloaded")
    plt.show()
    if(pred>=0.6):
        return True

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.3484 - accuracy: 0.8000
# [0.34840652346611023, 0.800000011920929]

# %%
predict('normaltrucks/11-NT.jpg')

# %%
predict('overtrucks/02-OT.jpg')
# Out:
# True

# %%
predict('overtrucks/68-OT.jpg')
# Out:
# True

# %%
predict('overtrucks/84-OT.jpg')
# Out:
# True

# %%
import cv2
import sqlite3
from tabulate import tabulate
import scanner
import datetime

cam=cv2.VideoCapture(0)
cv2.namedWindow("WebCam")
img_counter=0
while True:
    ret,frame=cam.read()
    if not ret:
        print("Failed to grab frame")
        break
    cv2.imshow("WebCam",frame)

    k = cv2.waitKey(1)
    if k%256==27:
        # ESC pressed
        print("Closing...")
        break

    elif k%256==32:
        # SPACE pressed
        img_name="opencv_frame_{}.jpg".format(img_counter)
        cv2.imwrite(img_name,frame)
        if(predict(img_name)):

            conn=sqlite3.connect('Magnusa.db')
            cur=conn.cursor()

            cur.execute("Select mapper_class from Vehicleclass") 
            result=cur.fetchall()
            fastag_data=scanner.decoder()
            tag=fastag_data.split(',')[0]
            fine=500
            cur.execute("Insert into Fine(fastag_id) values (?)",(tag,))
            conn.commit()
            cur.execute("SELECT EXISTS(SELECT 1 FROM Fine WHERE fastag_id=?)",(tag,))
            myresult=cur.fetchall()
            conn.commit()
            cur.close()

    #print("{} written!".format(img_name))
    img_counter+=1

cam.release()
cv2.destroyAllWindows()
# Out:
# Barcode: 100,12,LMV,ab123c123,500 | Type: QRCODE
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-42-a549d0b378c3> in <module>
#      35             tag=fastag_data.split(',')[0]
#      36             fine=500
# ---> 37             cur.execute("Insert into Fine(fastag_id) values (?)",(tag,))
#      38             conn.commit()
#      39             cur.execute("SELECT EXISTS(SELECT 1 FROM Fine WHERE fastag_id=?)",(tag,))
#
# OperationalError: database is locked

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter.filedialog import askopenfile
from PIL import Image, ImageTk
my_w = tk.Tk()
my_w.geometry("430x500")
my_w.title('Prototype')
my_font1=('times', 18, 'bold')
l1 = tk.Label(my_w,text='Add any photo of a commercial vehicle',width=30,font=my_font1)  
l1.grid(row=1,column=1)
b1 = tk.Button(my_w, text='Upload File', 
   width=20,command = lambda:upload_file())
b1.grid(row=2,column=1) 

def upload_file():
    global img, path
    f_types = [('testing', '*.jpg')]
    filename = filedialog.askopenfilename(filetypes=f_types)
    img = ImageTk.PhotoImage(file=filename)
    #path = filedialog.askopenfilename(initialdir=os.getcwd())
    predict(filename)
    b2 =tk.Button(my_w,image=img)
    b2.grid(row=3,column=1)

my_w.mainloop()

# %%
import sqlite3
from tabulate import tabulate
import scanner
import datetime

conn=sqlite3.connect('Magnusa.db')
cur=conn.cursor()

cur.execute("Select mapper_class from Vehicleclass") 
result=cur.fetchall()
fastag_data=scanner.decoder()
tag=fastag_data.split(',')[0]
fine=500
cur.execute("Insert into Fine(fastag_id) values (?)",(tag,))
conn.commit()
cur.execute("SELECT EXISTS(SELECT 1 FROM Fine WHERE fastag_id=?)",(tag,))
myresult=cur.fetchall()
conn.commit()
cur.close()
# Out:
# Barcode: 100,12,LMV,ab123c123,500 | Type: QRCODE
